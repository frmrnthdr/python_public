# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import warnings
warnings.filterwarnings('ignore')
x = np.arange(0.00, 1, 0.001)
y = np.arange(-1.0, 1.0, 0.01)
x, y = np.meshgrid(x, y)
z = y**2/x+np.log(2*np.cosh(y/x))
ax = plt.figure().gca(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.coolwarm)
ax.set_zlim(-50, 50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import warnings
warnings.filterwarnings('ignore')
x = np.arange(0.5, 5.5, 0.01)
y = np.arange(0.01, 5.01, 0.01)
x, y = np.meshgrid(x, y)
z = (y**2)/(15*x)
ax = plt.figure().gca(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.coolwarm)
ax.set_zlim(-0, 1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
J = np.arange(-5, 5, 0.01)
T = np.arange(0, 5, 0.01)
J, T = np.meshgrid(J, T)
z = 1/(J-T)
ax = plt.figure().gca(projection='3d')
ax.plot_surface(J, T, z, cmap=plt.cm.coolwarm)
ax.set_zlim(-0, 1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Owner\AppData\Local\Temp\ipykernel_9656\1016180739.py:9: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.figure().gca(projection='3d')

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import warnings
warnings.filterwarnings('ignore')
y = np.arange(0.1, 4.1, 0.01)
x = np.arange(0.1, 8.1, 0.01)
x, y = np.meshgrid(x, y)
z = -np.log(2)+(1/2)*((x-1)/x)+(1/12)*(((x-1)/x)**2)
ax = plt.figure().gca(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.coolwarm)
ax.set_zlim(-1, 1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
