# %% [markdown]
# 計算物理学の最終課題の没案

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib notebook
from skimage import measure
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

xl = np.linspace(-2, 2, 100)
X, Y, Z = np.meshgrid(xl, xl, xl)
F = np.tanh((X+Y)/Z)-X

verts, faces, normals, values = measure.marching_cubes(F, 0, spacing=[np.diff(xl)[0]]*3)
verts -= 3

fig = plt.figure()
axis = fig.add_subplot(111, projection='3d')
axis.set_title('implicit funtion')
axis.set_xlabel(r'$x$', fontsize=12)
axis.set_ylabel(r'$y$', fontsize=12)
axis.set_zlabel(r'$z$', fontsize=12)

axis.plot_trisurf(verts[:, 0], verts[:, 1], faces, verts[:, 2], cmap='coolwarm', lw=0, alpha=0.7,shade=True, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from skimage import measure

prrange = np.arange(0, 2, 0.01)
rrange = np.arange(-2, 2, 0.01)
a, t, x = np.meshgrid(rrange, prrange, rrange)
F = np.tanh((x + a)/t) - x

verts, faces, normals, values = measure.marching_cubes(F, 0, spacing=[np.diff(rrange)[0]]*3)
verts -= 3

fig = plt.figure()
axis = fig.add_subplot(111, projection='3d')
axis.set_xlabel('$t$')
axis.set_ylabel('$a$')
axis.set_zlabel('$x$')

axis.plot_trisurf(verts[:, 0], verts[:, 1], faces, verts[:, 2], cmap=plt.cm.coolwarm, lw=0, alpha=0.7,shade=True, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from skimage import measure
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

prrange = np.arange(0, 2, 0.01)
rrange = np.arange(-2, 2, 0.01)
a, t, x = np.meshgrid(rrange, prrange, rrange)
F = np.tanh(x/t) - x

verts, faces, normals, values = measure.marching_cubes(F, 0, spacing=[np.diff(rrange)[0]]*3)
verts -= 3

fig = plt.figure()
axis = fig.add_subplot(111, projection='3d')
axis.set_xlabel('$t$')
axis.set_ylabel('$a$')
axis.set_zlabel('$x$')

axis.plot_trisurf(verts[:, 0], verts[:, 1], faces, verts[:, 2], cmap=plt.cm.coolwarm, lw=0, alpha=0.7,shade=True, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from skimage import measure
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

prrange = np.arange(0, 2, 0.01)
rrange = np.arange(-2, 2, 0.01)
a, t, x = np.meshgrid(rrange, prrange, rrange)
F = np.tanh((x + a)/t) - x

verts, faces, normals, values = measure.marching_cubes(F, 0, spacing=[np.diff(rrange)[0]]*3)
verts -= 3

fig = plt.figure()
axis = fig.add_subplot(111, projection='3d')
axis.set_xlabel('$t$')
axis.set_ylabel('$a$')
axis.set_zlabel('$x$')

axis.plot_trisurf(verts[:, 0], verts[:, 1], faces, verts[:, 2], cmap=plt.cm.coolwarm, lw=0, alpha=0.7,shade=True, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from skimage import measure
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

prrange = np.arange(0, 2, 0.01)
rrange = np.arange(-2, 2, 0.01)
a, t, x = np.meshgrid(rrange, prrange, rrange)
F = np.tanh((x + 0.5)/t) - x

verts, faces, normals, values = measure.marching_cubes(F, 0, spacing=[np.diff(rrange)[0]]*3)
verts -= 3

fig = plt.figure()
axis = fig.add_subplot(111, projection='3d')
axis.set_xlabel('$t$')
axis.set_ylabel('$a$')
axis.set_zlabel('$x$')

axis.plot_trisurf(verts[:, 0], verts[:, 1], faces, verts[:, 2], cmap=plt.cm.coolwarm, lw=0, alpha=0.7,shade=True, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
t = np.arange(0, 2, 0.01)
x = np.arange(-2, 2, 0.01)
t, x = np.meshgrid(t, x)
y = np.tanh(x/t)

ax = plt.figure().gca(projection='3d')
ax.set_xlabel('$t$')
ax.set_ylabel('$x$')
ax.set_zlabel('$y$')

ax.plot_surface(t, x, y, cmap=plt.cm.coolwarm)
ax.plot_surface(t, x, x, cmap=plt.cm.coolwarm)
ax.set_zlim(-2, 2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
xrange = np.arange(0, 2, 0.005)
yrange = np.arange(-2, 2, 0.005)
X, Y = np.meshgrid(xrange,yrange)

#描画
Z=X*np.arctanh(Y) - Y
plt.contour(X, Y, Z, [0.0])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
xrange = np.arange(0, 2, 0.005)
yrange = np.arange(-2, 2, 0.005)
X, Y = np.meshgrid(xrange,yrange)

Z=X*np.arctanh(Y) - Y
plt.contour(X, Y, Z, [0.1])

plt.show()

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
x = np.arange(0, 5, 0.01)
y = np.arange(-1, 1, 0.01)
x, y = np.meshgrid(x, y)
z=x*np.arctanh(y) - y
ax = plt.figure().gca(projection='3d')
ax.set_xlabel('$t$')
ax.set_ylabel('$x$')
ax.set_zlabel('$y$')

ax.plot_surface(x, y, z, cmap=plt.cm.coolwarm)
ax.set_zlim(-1, 1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

x = np.arange(-1, 1, 0.01)
t = (x + 1/2)/np.arctanh(x)

plt.xlabel('$t$')
plt.ylabel('$x$')
plt.xlim(0, 2)

plt.plot(t, x)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 参考文献<br>
# [1] 2022年度17組計算物理学第2回講義資料"02_数値計算の基本.pdf"<br>
# [2] 桜井進. "Pythonでグラフ計算機｜Pythonで数学を学ぼう！　第18回 - 空間情報クラブ｜インフォマティクス運営のメディアサイト". 株式会社インフォマティクス. [club.informatix.co.jp/?p=16747](https://club.informatix.co.jp/?p=16747). \(2023年1月15日4:22 閲覧\)<br>
# [3] Matplotlib. "Interactive figures — Matplotlib 3.6.3 documentation". Matplotlib. [matplotlib.org/stable/users/explain/interactive.html](https://matplotlib.org/stable/users/explain/interactive.html). \(2023年1月15日2:26 閲覧\)<br>
# [4] Matplotlib. "The mplot3d toolkit — Matplotlib 3.6.3 documentation". Matplotlib. [matplotlib.org/stable/tutorials/toolkits/mplot3d.html](https://matplotlib.org/stable/tutorials/toolkits/mplot3d.html). \(2023年1月15日2:59 閲覧\)<br>
# [5] 大槻純也. "8.3. 【例題】イジング模型の平均場近似 — pythonで学ぶ計算物理 ドキュメント". 岡山大学. [physics.okayama-u.ac.jp/~otsuki/lecture/CompPhys2/root_find/ising_mf.html](http://www.physics.okayama-u.ac.jp/~otsuki/lecture/CompPhys2/root_find/ising_mf.html). \(2023年1月15日3:07 閲覧\)<br>
# [6] MathWorks ヘルプセンター. "三角形表面プロット - MATLAB trisurf - MathWorks 日本". The MathWorks, Inc. [jp.mathworks.com/help/matlab/ref/trisurf.html](https://jp.mathworks.com/help/matlab/ref/trisurf.html) \(2023年1月15日7:47 閲覧\) <br>
# [7] scikit-image. "Module: measure — skimage v0.19.2 docs". the scikit-image development team. [scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.marching_cubes](https://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.marching_cubes) \(2023年1月15日7:53 閲覧\) <br>
# [8] Matplotlib. "mpl_toolkits.mplot3d.axes3d.Axes3D — Matplotlib 3.6.3 documentation". Matplotlib. [matplotlib.org/stable/api/_as_gen/mpl_toolkits.mplot3d.axes3d.Axes3D.html#mpl_toolkits.mplot3d.axes3d.Axes3D.plot_surface](https://matplotlib.org/stable/api/_as_gen/mpl_toolkits.mplot3d.axes3d.Axes3D.html#mpl_toolkits.mplot3d.axes3d.Axes3D.plot_surface) \(2023年1月15日7:55 閲覧\)
